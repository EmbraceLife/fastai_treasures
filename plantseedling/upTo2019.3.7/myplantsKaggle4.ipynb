# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#数据收纳-Dataset-well-placed" data-toc-modified-id="数据收纳-Dataset-well-placed-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>数据收纳 Dataset well-placed</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#用as-fv的好处" data-toc-modified-id="用as-fv的好处-1.0.0.1"><span class="toc-item-num">1.0.0.1&nbsp;&nbsp;</span>用<code>as fv</code>的好处</a></span></li><li><span><a href="#提取常用地址" data-toc-modified-id="提取常用地址-1.0.0.2"><span class="toc-item-num">1.0.0.2&nbsp;&nbsp;</span>提取常用地址</a></span></li><li><span><a href="#洞察文件夹" data-toc-modified-id="洞察文件夹-1.0.0.3"><span class="toc-item-num">1.0.0.3&nbsp;&nbsp;</span>洞察文件夹</a></span></li><li><span><a href="#当前地址" data-toc-modified-id="当前地址-1.0.0.4"><span class="toc-item-num">1.0.0.4&nbsp;&nbsp;</span>当前地址</a></span></li><li><span><a href="#清空当前地址/input下所有内容" data-toc-modified-id="清空当前地址/input下所有内容-1.0.0.5"><span class="toc-item-num">1.0.0.5&nbsp;&nbsp;</span>清空当前地址/input下所有内容</a></span></li><li><span><a href="#复制-/kaggle/input-到-/kaggle/working/input/" data-toc-modified-id="复制-/kaggle/input-到-/kaggle/working/input/-1.0.0.6"><span class="toc-item-num">1.0.0.6&nbsp;&nbsp;</span>复制 /kaggle/input 到 /kaggle/working/input/</a></span></li><li><span><a href="#洞察数据地址中内容" data-toc-modified-id="洞察数据地址中内容-1.0.0.7"><span class="toc-item-num">1.0.0.7&nbsp;&nbsp;</span>洞察数据地址中内容</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#ResNet-50,-299,-0.25" data-toc-modified-id="ResNet-50,-299,-0.25-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>ResNet 50, 299, 0.25</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#洞察train-文件夹地址" data-toc-modified-id="洞察train-文件夹地址-2.0.0.1"><span class="toc-item-num">2.0.0.1&nbsp;&nbsp;</span>洞察train 文件夹地址</a></span></li><li><span><a href="#如何固定validation集" data-toc-modified-id="如何固定validation集-2.0.0.2"><span class="toc-item-num">2.0.0.2&nbsp;&nbsp;</span>如何固定validation集</a></span></li></ul></li></ul></li><li><span><a href="#data1-(299-大小-0.25-val)" data-toc-modified-id="data1-(299-大小-0.25-val)-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>data1 (299 大小 0.25 val)</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#用train,-test文件夹构建DataBunch" data-toc-modified-id="用train,-test文件夹构建DataBunch-2.1.0.1"><span class="toc-item-num">2.1.0.1&nbsp;&nbsp;</span>用train, test文件夹构建DataBunch</a></span></li><li><span><a href="#了解data的构造" data-toc-modified-id="了解data的构造-2.1.0.2"><span class="toc-item-num">2.1.0.2&nbsp;&nbsp;</span>了解data的构造</a></span></li><li><span><a href="#查看图片" data-toc-modified-id="查看图片-2.1.0.3"><span class="toc-item-num">2.1.0.3&nbsp;&nbsp;</span>查看图片</a></span></li></ul></li></ul></li><li><span><a href="#Resnet50-CNN" data-toc-modified-id="Resnet50-CNN-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Resnet50 CNN</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#learning-rate-finder-具体工作原理是什么？(done)" data-toc-modified-id="learning-rate-finder-具体工作原理是什么？(done)-2.2.0.1"><span class="toc-item-num">2.2.0.1&nbsp;&nbsp;</span>learning rate finder 具体工作原理是什么？(done)</a></span></li></ul></li></ul></li><li><span><a href="#封冻训练" data-toc-modified-id="封冻训练-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>封冻训练</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#fit_one_cycle的学习率该怎么设置？(done)" data-toc-modified-id="fit_one_cycle的学习率该怎么设置？(done)-2.3.0.1"><span class="toc-item-num">2.3.0.1&nbsp;&nbsp;</span><code>fit_one_cycle</code>的学习率该怎么设置？(done)</a></span></li><li><span><a href="#改变模型保存地址" data-toc-modified-id="改变模型保存地址-2.3.0.2"><span class="toc-item-num">2.3.0.2&nbsp;&nbsp;</span>改变模型保存地址</a></span></li></ul></li></ul></li><li><span><a href="#解冻训练" data-toc-modified-id="解冻训练-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>解冻训练</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#大范围训练1e-6-1e-4" data-toc-modified-id="大范围训练1e-6-1e-4-2.4.0.1"><span class="toc-item-num">2.4.0.1&nbsp;&nbsp;</span>大范围训练1e-6 1e-4</a></span></li><li><span><a href="#对比-(1e-4,1e-3)" data-toc-modified-id="对比-(1e-4,1e-3)-2.4.0.2"><span class="toc-item-num">2.4.0.2&nbsp;&nbsp;</span>对比 (1e-4,1e-3)</a></span></li><li><span><a href="#对比-1e-3-1e-2" data-toc-modified-id="对比-1e-3-1e-2-2.4.0.3"><span class="toc-item-num">2.4.0.3&nbsp;&nbsp;</span>对比 1e-3 1e-2</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#ResNet-50,-350,-0.25-val" data-toc-modified-id="ResNet-50,-350,-0.25-val-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>ResNet 50, 350, 0.25 val</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#查看valid-集中的图片，以确认valid集保持不变" data-toc-modified-id="查看valid-集中的图片，以确认valid集保持不变-3.0.0.1"><span class="toc-item-num">3.0.0.1&nbsp;&nbsp;</span>查看valid 集中的图片，以确认valid集保持不变</a></span></li><li><span><a href="#重新生成DataBunch,-变形后图片更大，但valid集数据一致性不变" data-toc-modified-id="重新生成DataBunch,-变形后图片更大，但valid集数据一致性不变-3.0.0.2"><span class="toc-item-num">3.0.0.2&nbsp;&nbsp;</span>重新生成DataBunch, 变形后图片更大，但valid集数据一致性不变</a></span></li></ul></li></ul></li><li><span><a href="#Data2-(350-0.25-val)" data-toc-modified-id="Data2-(350-0.25-val)-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Data2 (350 0.25 val)</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#模型解读功能到底怎么用呢？" data-toc-modified-id="模型解读功能到底怎么用呢？-3.1.0.1"><span class="toc-item-num">3.1.0.1&nbsp;&nbsp;</span>模型解读功能到底怎么用呢？</a></span></li></ul></li></ul></li><li><span><a href="#上轮最优模型-stg-2-unf-1e43" data-toc-modified-id="上轮最优模型-stg-2-unf-1e43-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>上轮最优模型 stg-2-unf-1e43</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#加载新数据给模型" data-toc-modified-id="加载新数据给模型-3.2.0.1"><span class="toc-item-num">3.2.0.1&nbsp;&nbsp;</span>加载新数据给模型</a></span></li><li><span><a href="#模型+新数据下的学习率" data-toc-modified-id="模型+新数据下的学习率-3.2.0.2"><span class="toc-item-num">3.2.0.2&nbsp;&nbsp;</span>模型+新数据下的学习率</a></span></li></ul></li><li><span><a href="#封冻训练" data-toc-modified-id="封冻训练-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>封冻训练</a></span><ul class="toc-item"><li><span><a href="#1e-6,1e-5-的表现" data-toc-modified-id="1e-6,1e-5-的表现-3.2.1.1"><span class="toc-item-num">3.2.1.1&nbsp;&nbsp;</span>1e-6,1e-5 的表现</a></span></li><li><span><a href="#1e-5,1e-4的表现" data-toc-modified-id="1e-5,1e-4的表现-3.2.1.2"><span class="toc-item-num">3.2.1.2&nbsp;&nbsp;</span>1e-5,1e-4的表现</a></span></li><li><span><a href="#1e-4,1e-3的表现" data-toc-modified-id="1e-4,1e-3的表现-3.2.1.3"><span class="toc-item-num">3.2.1.3&nbsp;&nbsp;</span>1e-4,1e-3的表现</a></span></li></ul></li><li><span><a href="#解冻stg-3-large-1e54，再训练" data-toc-modified-id="解冻stg-3-large-1e54，再训练-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>解冻stg-3-large-1e54，再训练</a></span><ul class="toc-item"><li><span><a href="#lr-=-(1e-5,-1e-4)" data-toc-modified-id="lr-=-(1e-5,-1e-4)-3.2.2.1"><span class="toc-item-num">3.2.2.1&nbsp;&nbsp;</span>lr = (1e-5, 1e-4)</a></span></li><li><span><a href="#lr-=-(1e-6,-1e-5)" data-toc-modified-id="lr-=-(1e-6,-1e-5)-3.2.2.2"><span class="toc-item-num">3.2.2.2&nbsp;&nbsp;</span>lr = (1e-6, 1e-5)</a></span></li><li><span><a href="#lr-=-(1e-4,-1e-3)" data-toc-modified-id="lr-=-(1e-4,-1e-3)-3.2.2.3"><span class="toc-item-num">3.2.2.3&nbsp;&nbsp;</span>lr = (1e-4, 1e-3)</a></span></li></ul></li><li><span><a href="#尝试-stg-3-large-43-模型" data-toc-modified-id="尝试-stg-3-large-43-模型-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>尝试 stg-3-large-43 模型</a></span><ul class="toc-item"><li><span><a href="#lr-=-(1e-5,1e-4)" data-toc-modified-id="lr-=-(1e-5,1e-4)-3.2.3.1"><span class="toc-item-num">3.2.3.1&nbsp;&nbsp;</span>lr = (1e-5,1e-4)</a></span></li><li><span><a href="#lr-=-(1e-6,-1e-5)" data-toc-modified-id="lr-=-(1e-6,-1e-5)-3.2.3.2"><span class="toc-item-num">3.2.3.2&nbsp;&nbsp;</span>lr = (1e-6, 1e-5)</a></span></li><li><span><a href="#lr-=-(1e-4,-1e-3)" data-toc-modified-id="lr-=-(1e-4,-1e-3)-3.2.3.3"><span class="toc-item-num">3.2.3.3&nbsp;&nbsp;</span>lr = (1e-4, 1e-3)</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#生成预测结果" data-toc-modified-id="生成预测结果-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>生成预测结果</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#stg-4-43-unf-1e43" data-toc-modified-id="stg-4-43-unf-1e43-4.0.0.1"><span class="toc-item-num">4.0.0.1&nbsp;&nbsp;</span>stg-4-43-unf-1e43</a></span></li><li><span><a href="#stg-4-43-unf-1e54" data-toc-modified-id="stg-4-43-unf-1e54-4.0.0.2"><span class="toc-item-num">4.0.0.2&nbsp;&nbsp;</span>stg-4-43-unf-1e54</a></span></li></ul></li></ul></li></ul></li></ul></div>

# %% [markdown]
# Thanks to [kharbanda](https://www.kaggle.com/kharbanda) for sharing the [original kernel](https://www.kaggle.com/kharbanda/fast-ai-v1/)

# %% [markdown]
# # 数据收纳 Dataset well-placed

# %% [markdown]
# #### 用`as fv`的好处

# %%
import fastai.vision as fv # why use fv? fv的好处

# %% [markdown]
# #### 提取常用地址

# %%
path_input = fv.Path('/kaggle/input') # most used path address 常用地址
path_working = fv.Path('/kaggle/working')

# %% [markdown]
# #### 洞察文件夹

# %%
path_input.ls() # # check inside 洞察
# Out:
# [PosixPath('/kaggle/input/sample_submission.csv'),
#  PosixPath('/kaggle/input/train'),
#  PosixPath('/kaggle/input/test')]

# %%
path_working.ls()
# Out:
# [PosixPath('/kaggle/working/.ipynb_checkpoints'),
#  PosixPath('/kaggle/working/__notebook_source__.ipynb')]

# %% [markdown]
# #### 当前地址

# %%
# !pwd # current directory 当前地址
# Out:
# /kaggle/working

# %% [markdown]
# #### 清空当前地址/input下所有内容

# %%
# !rm -rf input  #  remove（清空） everything on /kaggle/working/input/

# %% [markdown]
# #### 复制 /kaggle/input 到 /kaggle/working/input/

# %%
# !cp -r ../input . # copy (复制) /kaggle/input to (到) /kaggle/working/input/ 
# /kaggle/working

# %% [markdown]
# #### 洞察数据地址中内容

# %%
path_data = fv.Path('/kaggle/working/input') # 数据地址

# %%
path_data.ls() # no validation set, but has test set 发现有test集没有valid 集
# Out:
# [PosixPath('/kaggle/working/input/sample_submission.csv'),
#  PosixPath('/kaggle/working/input/train'),
#  PosixPath('/kaggle/working/input/test')]

# %% [markdown]
# # ResNet 50, 299, 0.25

# %% [markdown]
# #### 洞察train 文件夹地址

# %%
path_train = fv.Path('/kaggle/working/input/train') # need train folder

# %%
path_train.ls() # 洞察， 每个子folder就是一个类别
# Out:
# [PosixPath('/kaggle/working/input/train/Common Chickweed'),
#  PosixPath('/kaggle/working/input/train/Scentless Mayweed'),
#  PosixPath('/kaggle/working/input/train/Cleavers'),
#  PosixPath('/kaggle/working/input/train/Common wheat'),
#  PosixPath('/kaggle/working/input/train/Shepherds Purse'),
#  PosixPath('/kaggle/working/input/train/Black-grass'),
#  PosixPath('/kaggle/working/input/train/Small-flowered Cranesbill'),
#  PosixPath('/kaggle/working/input/train/Charlock'),
#  PosixPath('/kaggle/working/input/train/Loose Silky-bent'),
#  PosixPath('/kaggle/working/input/train/Sugar beet'),
#  PosixPath('/kaggle/working/input/train/Maize'),
#  PosixPath('/kaggle/working/input/train/Fat Hen')]

# %% [markdown]
# #### 如何固定validation集

# %%
fv.np.random.seed(42) # 确保valid集的不变

# %% [markdown]
# ## data1 (299 大小 0.25 val)

# %% [markdown]
# #### 用train, test文件夹构建DataBunch
# * 注意探索内部结构

# %%
data = fv.ImageDataBunch.from_folder(path_train, # 只有train，没有valid folder
                                     test='../test', # 有test folder
                                     ds_tfms=fv.get_transforms(), # 变形图片
                                     valid_pct=0.25, # 25% validation 75% training
                                     size=299, # 图片变形后大小
                                     bs=32, # 小批量的大小
                                     num_workers=0) # 确保内存够跑
data.normalize(fv.imagenet_stats) # 对图片做均值方差处理
# 观察：299是指图片的长与宽
# 尝试：64， 128， 256， 512？
# Out:
# ImageDataBunch;
#
# Train: LabelList (3563 items)
# x: ImageList
# Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299)
# y: CategoryList
# Common Chickweed,Common Chickweed,Common Chickweed,Common Chickweed,Common Chickweed
# Path: /kaggle/working/input/train;
#
# Valid: LabelList (1187 items)
# x: ImageList
# Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299)
# y: CategoryList
# Sugar beet,Scentless Mayweed,Common Chickweed,Black-grass,Shepherds Purse
# Path: /kaggle/working/input/train;
#
# Test: LabelList (794 items)
# x: ImageList
# Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299)
# y: EmptyLabelList
# ,,,,
# Path: /kaggle/working/input/train

# %% [markdown]
# #### 了解data的构造

# %%
data.batch_size # data 有很多函数和属性
# Out:
# 32

# %%
data.__class__
# Out:
# fastai.vision.data.ImageDataBunch

# %%
data.path # data 所在地址
# Out:
# PosixPath('/kaggle/working/input/train')

# %%
print(data.classes) # 查看类别及数量
len(data.classes),data.c
# Out:
# ['Black-grass', 'Charlock', 'Cleavers', 'Common Chickweed', 'Common wheat', 'Fat Hen', 'Loose Silky-bent', 'Maize', 'Scentless Mayweed', 'Shepherds Purse', 'Small-flowered Cranesbill', 'Sugar beet']
# (12, 12)

# %% [markdown]
# #### 查看图片

# %%
data.show_batch(rows=1,figsize=(7,6)) # 这是模型要处理的图片状态吗？done
# 应该是的，毕竟是从data里出来的数据；
# 发现：像素清晰度不一
# 尝试1：清晰度更低图片，如128

# %%
data.show_batch(rows=1,figsize=(7,6))

# %% [markdown]
# ## Resnet50 CNN

# %%
learn = fv.create_cnn(data,
                      fv.models.resnet50, # 选择模型框架
                      metrics=fv.error_rate)
# 尝试2: 用ResNet152看看效果
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /tmp/.torch/models/resnet50-19c8e357.pth
# 100%|██████████| 102502400/102502400 [00:01<00:00, 88924667.95it/s]

# %% [markdown]
# #### learning rate finder 具体工作原理是什么？(done)

# %% [markdown]
# ```python
# learn.lr_find?
#
# Signature: learn.lr_find(start_lr:Union[float, Collection[float]]=1e-07,
#                          end_lr:Union[float, Collection[float]]=10, # 探索空间非常大
#                          num_it:int=100, # 分割成100份尝试
#                          stop_div:bool=True, # 一旦变差，自动停止
#                          wd:float=None)
#
# Docstring: Explore lr from `start_lr` to `end_lr` over `num_it` iterations in `learn`.
#     If `stop_div`, stops when loss diverges.
#
#     File:      /opt/conda/lib/python3.6/site-packages/fastai/train.py
# Type:      method
# ```

# %%
learn.lr_find() # 具体工作原理是什么？(done)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot() # x, y 分别对应什么？(done)
# x = lr, y = loss of each trial

# %% [markdown]
# ## 封冻训练

# %% [markdown]
# #### `fit_one_cycle`的学习率该怎么设置？(done)
# 1e-2 斜率较大
# ```python
# def fit_one_cycle(learn:Learner,
#                               cyc_len:int,
#                               max_lr:Union[Floats,slice]=defaults.lr,
#                               moms:Tuple[float,float]=(0.95,0.85),
#                               div_factor:float=25.,
#                               pct_start:float=0.3,
#                               final_div:float=None,
#                               wd:float=None, callbacks:Optional[CallbackList]=None, tot_epochs:int=None, start_epoch:int=None)->None:
#     "Fit a model following the 1cycle policy."
#
# ```

# %%
learn.fit_one_cycle(6,slice(1e-2)) # 观察：train loss < val loss, 没有欠拟合
# Out:
# Total time: 24:37 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.977750</td>
#       <td>0.427568</td>
#       <td>0.147430</td>
#       <td>04:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.533636</td>
#       <td>0.303666</td>
#       <td>0.101938</td>
#       <td>04:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.370783</td>
#       <td>0.190443</td>
#       <td>0.060657</td>
#       <td>04:05</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.264522</td>
#       <td>0.156239</td>
#       <td>0.048020</td>
#       <td>04:04</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.177894</td>
#       <td>0.135476</td>
#       <td>0.037068</td>
#       <td>04:05</td>
#     </tr>
# ...

# %% [markdown]
# #### 改变模型保存地址

# %%
learn.model_dir = path_working # 设置生成保存模型所在地
learn.save('stg-1', return_path=True) # not into path_data/models/
# Out:
# PosixPath('/kaggle/working/stg-1.pth')

# %%
learn.lr_find() # 6次后，lr长什么样子？
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot() # 是否应该持续微调lr训练？（在解冻前）
# 可以试试
# 应该如何选择最优lr区间呢？1e-6 to 1e-4 or to 1e-3?

# %% [markdown]
# ## 解冻训练

# %%
learn.unfreeze() # 解冻所有封冻层

# %%
learn.lr_find() # 解冻会影响吗？
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot() # 猜想不会
# 但事实上，做出的图却不同！！！！
# 应该如何选择最优lr区间呢？1e-6 to 1e-4 or to 1e-3?

# %% [markdown]
# #### 大范围训练1e-6 1e-4

# %%
learn.fit_one_cycle(6,max_lr=slice(1e-6,1e-4)) # 学习率范围是如何被使用的？
# lr 过小，error 过慢
# Out:
# Total time: 27:56 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.127538</td>
#       <td>0.131621</td>
#       <td>0.031171</td>
#       <td>04:39</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.111812</td>
#       <td>0.130494</td>
#       <td>0.032013</td>
#       <td>04:38</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.112539</td>
#       <td>0.120642</td>
#       <td>0.028644</td>
#       <td>04:39</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.092372</td>
#       <td>0.122845</td>
#       <td>0.031171</td>
#       <td>04:39</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.083454</td>
#       <td>0.121425</td>
#       <td>0.029486</td>
#       <td>04:40</td>
#     </tr>
# ...

# %%
learn.save('stg-2-unf-1e64', return_path=True) # not into path_data/models/
# Out:
# PosixPath('/kaggle/working/stg-2-unf-1e64.pth')

# %% [markdown]
# #### 对比 (1e-4,1e-3)

# %%
learn.load('stg-1')
learn.unfreeze()
learn.fit_one_cycle(6,max_lr=slice(1e-4,1e-3)) # 学习率范围是如何被使用的？
# lr 合适， error 合适
# Out:
# Total time: 27:55 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.258221</td>
#       <td>0.608041</td>
#       <td>0.133951</td>
#       <td>04:39</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.396586</td>
#       <td>0.266185</td>
#       <td>0.090986</td>
#       <td>04:38</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.305675</td>
#       <td>0.232106</td>
#       <td>0.071609</td>
#       <td>04:38</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.167016</td>
#       <td>0.136525</td>
#       <td>0.040438</td>
#       <td>04:39</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.096817</td>
#       <td>0.099684</td>
#       <td>0.028644</td>
#       <td>04:39</td>
#     </tr>
# ...

# %%
learn.save('stg-2-unf-1e43', return_path=True) # 保存且输出地址
# Out:
# PosixPath('/kaggle/working/stg-2-unf-1e43.pth')

# %% [markdown]
# #### 对比 1e-3 1e-2

# %%
learn.load('stg-1') 
learn.data
# Out:
# ImageDataBunch;
#
# Train: LabelList (3563 items)
# x: ImageList
# Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299)
# y: CategoryList
# Common Chickweed,Common Chickweed,Common Chickweed,Common Chickweed,Common Chickweed
# Path: /kaggle/working/input/train;
#
# Valid: LabelList (1187 items)
# x: ImageList
# Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299)
# y: CategoryList
# Sugar beet,Scentless Mayweed,Common Chickweed,Black-grass,Shepherds Purse
# Path: /kaggle/working/input/train;
#
# Test: LabelList (794 items)
# x: ImageList
# Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299)
# y: EmptyLabelList
# ,,,,
# Path: /kaggle/working/input/train

# %%
learn.unfreeze()
learn.fit_one_cycle(4,max_lr=slice(1e-3,1e-2))
# lr 过大， error 过大
# Out:
# Total time: 18:35 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.998707</td>
#       <td>1.459306</td>
#       <td>0.385004</td>
#       <td>04:39</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.789148</td>
#       <td>0.828296</td>
#       <td>0.248526</td>
#       <td>04:38</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.454319</td>
#       <td>0.245992</td>
#       <td>0.092671</td>
#       <td>04:38</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.259752</td>
#       <td>0.187853</td>
#       <td>0.064027</td>
#       <td>04:39</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit_one_cycle(4,max_lr=slice(1e-3,1e-2)) # 上面趋势不错，所以继续
# not really continued to train as I imagined
# 但至少10epochs, error依旧很高
# Out:
# Total time: 18:34 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.501222</td>
#       <td>2.023172</td>
#       <td>0.478517</td>
#       <td>04:38</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.210190</td>
#       <td>1.002692</td>
#       <td>0.359730</td>
#       <td>04:39</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.763813</td>
#       <td>0.377916</td>
#       <td>0.132266</td>
#       <td>04:38</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.475465</td>
#       <td>0.288088</td>
#       <td>0.100253</td>
#       <td>04:38</td>
#     </tr>
#   </tbody>
# </table>

# %%
# learn.save('stg-3', return_path=True) # 不必保存

# %% [markdown]
# # ResNet 50, 350, 0.25 val

# %% [markdown]
# #### 查看valid 集中的图片，以确认valid集保持不变

# %%
data.show_batch(rows=1,ds_type=fv.DatasetType.Valid, figsize=(7,6))

# %% [markdown]
# #### 重新生成DataBunch, 变形后图片更大，但valid集数据一致性不变

# %%
fv.np.random.seed(42) # 重新生成DataBunch, 变形后图片更大，但valid集数据一致性不变

# %% [markdown]
# ## Data2 (350 0.25 val)

# %%
data = fv.ImageDataBunch.from_folder(path_train,
                                  test='../test', 
                                  ds_tfms=fv.get_transforms(),
                                  valid_pct=0.25,
                                  size=350, # 更大了，但这些数字是如何选择的呢？
                                  bs=32,
                                  num_workers=0)
data.normalize(fv.imagenet_stats)
# Out:
# ImageDataBunch;
#
# Train: LabelList (3563 items)
# x: ImageList
# Image (3, 350, 350),Image (3, 350, 350),Image (3, 350, 350),Image (3, 350, 350),Image (3, 350, 350)
# y: CategoryList
# Common Chickweed,Common Chickweed,Common Chickweed,Common Chickweed,Common Chickweed
# Path: /kaggle/working/input/train;
#
# Valid: LabelList (1187 items)
# x: ImageList
# Image (3, 350, 350),Image (3, 350, 350),Image (3, 350, 350),Image (3, 350, 350),Image (3, 350, 350)
# y: CategoryList
# Sugar beet,Scentless Mayweed,Common Chickweed,Black-grass,Shepherds Purse
# Path: /kaggle/working/input/train;
#
# Test: LabelList (794 items)
# x: ImageList
# Image (3, 350, 350),Image (3, 350, 350),Image (3, 350, 350),Image (3, 350, 350),Image (3, 350, 350)
# y: EmptyLabelList
# ,,,,
# Path: /kaggle/working/input/train

# %%
data.show_batch(rows=1,ds_type=fv.DatasetType.Valid, figsize=(7,6)) # 一致

# %% [markdown]
# #### 模型解读功能到底怎么用呢？

# %%
fv.ClassificationInterpretation.from_learner?

# %%
interp = fv.ClassificationInterpretation.from_learner(learn)

# %%
interp.y_true.numpy()
# Out:
# array([11,  8,  3,  0, ...,  8,  9, 10, 11])

# %%
interp.pred_class.numpy()
# Out:
# array([11,  8,  3,  0, ...,  8,  9, 10, 11])

# %%
data.classes
# Out:
# ['Black-grass',
#  'Charlock',
#  'Cleavers',
#  'Common Chickweed',
#  'Common wheat',
#  'Fat Hen',
#  'Loose Silky-bent',
#  'Maize',
#  'Scentless Mayweed',
#  'Shepherds Purse',
#  'Small-flowered Cranesbill',
#  'Sugar beet']

# %%
from sklearn import metrics

# %% [markdown]
# ```python
# metrics.classification_report?
#
# Signature: metrics.classification_report(y_true,
#                                                              y_pred,
#                                                              labels=None,
#                                                              target_names=None,
#                                                              sample_weight=None,
#                                                              digits=2, output_dict=False)
# Docstring:
# Build a text report showing the main classification metrics
#
# Read more in the :ref:`User Guide <classification_report>`.
# ```

# %%
print(metrics.classification_report(interp.y_true.numpy(), interp.pred_class.numpy(),target_names =data.classes))
# Out:
#                            precision    recall  f1-score   support
#
#               Black-grass       0.63      0.54      0.58        61
#                  Charlock       0.97      0.94      0.96       105
#                  Cleavers       0.84      0.91      0.87        68
#          Common Chickweed       0.94      0.96      0.95       170
#              Common wheat       0.94      0.87      0.90        54
#                   Fat Hen       0.98      0.91      0.94       129
#          Loose Silky-bent       0.81      0.87      0.84       150
#                     Maize       0.89      0.94      0.91        51
#         Scentless Mayweed       0.83      0.98      0.90       130
#           Shepherds Purse       0.94      0.62      0.75        53
# Small-flowered Cranesbill       1.00      0.98      0.99       124
#                Sugar beet       0.96      0.92      0.94        92
#
#                 micro avg       0.90      0.90      0.90      1187
# ...

# %% [markdown]
# ## 上轮最优模型 stg-2-unf-1e43

# %%
# learn.save('stg-2') # 手误，应该是learn.load('stg-2'), 极可能影响后面的效果！！！！！
learn.load('stg-2-unf-1e43') # 这里是下次跑时要用的正确代码
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (3563 items)
# x: ImageList
# Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299)
# y: CategoryList
# Common Chickweed,Common Chickweed,Common Chickweed,Common Chickweed,Common Chickweed
# Path: /kaggle/working/input/train;
#
# Valid: LabelList (1187 items)
# x: ImageList
# Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299)
# y: CategoryList
# Sugar beet,Scentless Mayweed,Common Chickweed,Black-grass,Shepherds Purse
# Path: /kaggle/working/input/train;
#
# Test: LabelList (794 items)
# x: ImageList
# Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299)
# y: EmptyLabelList
# ,,,,
# Path: /kaggle/working/input/train, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
# ...

# %% [markdown]
# #### 加载新数据给模型
# 可见，加载的模型，携带了原来的数据

# %%
learn.data=data # 链接新的数据，还是置换新数据？需要检验
learn.data
# Out:
# ImageDataBunch;
#
# Train: LabelList (3563 items)
# x: ImageList
# Image (3, 350, 350),Image (3, 350, 350),Image (3, 350, 350),Image (3, 350, 350),Image (3, 350, 350)
# y: CategoryList
# Common Chickweed,Common Chickweed,Common Chickweed,Common Chickweed,Common Chickweed
# Path: /kaggle/working/input/train;
#
# Valid: LabelList (1187 items)
# x: ImageList
# Image (3, 350, 350),Image (3, 350, 350),Image (3, 350, 350),Image (3, 350, 350),Image (3, 350, 350)
# y: CategoryList
# Sugar beet,Scentless Mayweed,Common Chickweed,Black-grass,Shepherds Purse
# Path: /kaggle/working/input/train;
#
# Test: LabelList (794 items)
# x: ImageList
# Image (3, 350, 350),Image (3, 350, 350),Image (3, 350, 350),Image (3, 350, 350),Image (3, 350, 350)
# y: EmptyLabelList
# ,,,,
# Path: /kaggle/working/input/train

# %% [markdown]
# #### 模型+新数据下的学习率

# %%
learn.lr_find()
learn.recorder.plot() # 这里的学习率该怎么读？
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %% [markdown]
# ### 封冻训练

# %% [markdown]
# #### 1e-6,1e-5 的表现

# %%
learn.fit_one_cycle(4,max_lr=slice(1e-6,1e-5)) 
# 疑似过拟合
# Out:
# Total time: 22:12 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.053293</td>
#       <td>0.090139</td>
#       <td>0.026116</td>
#       <td>05:37</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.059069</td>
#       <td>0.082851</td>
#       <td>0.021061</td>
#       <td>05:31</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.053310</td>
#       <td>0.083328</td>
#       <td>0.019377</td>
#       <td>05:32</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.052230</td>
#       <td>0.083378</td>
#       <td>0.021061</td>
#       <td>05:31</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stg-3-large-1e65', return_path=True)
# Out:
# PosixPath('/kaggle/working/stg-3-large-1e65.pth')

# %% [markdown]
# #### 1e-5,1e-4的表现

# %%
learn.load('stg-2-unf-1e43')
learn.data = data
learn.fit_one_cycle(4,max_lr=slice(1e-5,1e-4)) 
# 疑似过拟合
# Out:
# Total time: 22:00 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.061056</td>
#       <td>0.090570</td>
#       <td>0.023589</td>
#       <td>05:30</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.054208</td>
#       <td>0.089867</td>
#       <td>0.020219</td>
#       <td>05:29</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.048492</td>
#       <td>0.078078</td>
#       <td>0.018534</td>
#       <td>05:30</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.037151</td>
#       <td>0.082657</td>
#       <td>0.023589</td>
#       <td>05:30</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stg-3-large-1e54', return_path=True) # not into path_data/models/
# Out:
# PosixPath('/kaggle/working/stg-3-large-1e54.pth')

# %% [markdown]
# #### 1e-4,1e-3的表现

# %%
learn.load('stg-2-unf-1e43')
learn.data = data
learn.fit_one_cycle(4,max_lr=slice(1e-4,1e-3)) 
# 一切正常，没有过拟合，但表现不是最好
# 但也许，它才是最优选择？
# Out:
# Total time: 21:51 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.192007</td>
#       <td>0.742618</td>
#       <td>0.151643</td>
#       <td>05:27</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.260260</td>
#       <td>0.192528</td>
#       <td>0.051390</td>
#       <td>05:27</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.140362</td>
#       <td>0.097000</td>
#       <td>0.029486</td>
#       <td>05:27</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.077927</td>
#       <td>0.085659</td>
#       <td>0.024431</td>
#       <td>05:27</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stg-3-large-1e43', return_path=True) # not into path_data/models/
# Out:
# PosixPath('/kaggle/working/stg-3-large-1e43.pth')

# %% [markdown]
# ### 解冻stg-3-large-1e54，再训练
# 这次(1e-5,1e-4) 是最优！
# => 事后总结：但也许 (1e-4, 1e-3) 才是？

# %% [markdown]
# #### lr = (1e-5, 1e-4)

# %%
learn.load('stg-3-large-1e54')  # which model to choose?
learn.data = data
learn.unfreeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(4,max_lr=slice(1e-5,1e-4)) 
# 没有过拟合，但效果无改进
# Out:
# Total time: 21:51 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.037211</td>
#       <td>0.079017</td>
#       <td>0.019377</td>
#       <td>05:28</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.042215</td>
#       <td>0.083154</td>
#       <td>0.019377</td>
#       <td>05:27</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.024880</td>
#       <td>0.082597</td>
#       <td>0.019377</td>
#       <td>05:27</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.021013</td>
#       <td>0.078259</td>
#       <td>0.019377</td>
#       <td>05:27</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stg-4-unf-1e54', return_path=True) # not into path_data/models/
# Out:
# PosixPath('/kaggle/working/stg-4-unf-1e54.pth')

# %% [markdown]
# #### lr = (1e-6, 1e-5)

# %%
learn.load('stg-3-large-1e54')  # which model to choose?
learn.data = data
learn.unfreeze()
learn.fit_one_cycle(4,max_lr=slice(1e-6,1e-5)) 
# 疑似过拟合
# Out:
# Total time: 21:51 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.032500</td>
#       <td>0.079787</td>
#       <td>0.021904</td>
#       <td>05:27</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.032604</td>
#       <td>0.075084</td>
#       <td>0.018534</td>
#       <td>05:27</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.037657</td>
#       <td>0.077548</td>
#       <td>0.021061</td>
#       <td>05:27</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.038655</td>
#       <td>0.076688</td>
#       <td>0.020219</td>
#       <td>05:27</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stg-4-unf-1e65', return_path=True) # not into path_data/models/
# Out:
# PosixPath('/kaggle/working/stg-4-unf-1e65.pth')

# %% [markdown]
# #### lr = (1e-4, 1e-3)

# %%
learn.load('stg-3-large-1e54')  # which model to choose?
learn.data = data
learn.unfreeze()
learn.fit_one_cycle(4,max_lr=slice(1e-4,1e-3)) 
# 无过拟合，结果不差
# Out:
# Total time: 21:47 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.191889</td>
#       <td>0.594392</td>
#       <td>0.144061</td>
#       <td>05:28</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.260894</td>
#       <td>0.140538</td>
#       <td>0.042123</td>
#       <td>05:26</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.136565</td>
#       <td>0.100779</td>
#       <td>0.026959</td>
#       <td>05:27</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.067637</td>
#       <td>0.073632</td>
#       <td>0.019377</td>
#       <td>05:26</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stg-4-unf-1e43', return_path=True) # not into path_data/models/
# Out:
# PosixPath('/kaggle/working/stg-4-unf-1e43.pth')

# %% [markdown]
# ### 尝试 stg-3-large-43 模型

# %%
learn = fv.cnn_learner(data,
                      fv.models.resnet50, # 选择模型框架
                      metrics=fv.error_rate, model_dir=base_dir)
# 尝试2: 用ResNet152看看效果
learn.load('stg-3-large-1e43')  # which model to choose?
learn.data = data
learn.unfreeze()
# Out:
# /usr/local/lib/python3.6/dist-packages/fastai/vision/learner.py:93: UserWarning: `create_cnn` is deprecated and is now named `cnn_learner`.
#   warn("`create_cnn` is deprecated and is now named `cnn_learner`.")

# %%
learn.data
# Out:
# ImageDataBunch;
#
# Train: LabelList (3563 items)
# x: ImageList
# Image (3, 350, 350),Image (3, 350, 350),Image (3, 350, 350),Image (3, 350, 350),Image (3, 350, 350)
# y: CategoryList
# Maize,Maize,Maize,Maize,Maize
# Path: train;
#
# Valid: LabelList (1187 items)
# x: ImageList
# Image (3, 350, 350),Image (3, 350, 350),Image (3, 350, 350),Image (3, 350, 350),Image (3, 350, 350)
# y: CategoryList
# Fat Hen,Black-grass,Loose Silky-bent,Common Chickweed,Shepherds Purse
# Path: train;
#
# Test: LabelList (794 items)
# x: ImageList
# Image (3, 350, 350),Image (3, 350, 350),Image (3, 350, 350),Image (3, 350, 350),Image (3, 350, 350)
# y: EmptyLabelList
# ,,,,
# Path: train

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %% [markdown]
# #### lr = (1e-5,1e-4)

# %%
learn.load('stg-3-large-1e43')  # which model to choose?
learn.data = data
learn.unfreeze()
learn.fit_one_cycle(4,max_lr=slice(1e-5,1e-4)) 
# seemingly slightly overfitting
# Out:
# Total time: 23:39 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.067411</td>
#       <td>0.030653</td>
#       <td>0.010110</td>
#       <td>05:59</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.063587</td>
#       <td>0.030012</td>
#       <td>0.009267</td>
#       <td>05:54</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.048370</td>
#       <td>0.026113</td>
#       <td>0.008425</td>
#       <td>05:55</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.043551</td>
#       <td>0.026494</td>
#       <td>0.009267</td>
#       <td>05:50</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stg-4-43-unf-1e54', return_path=True) # not into path_data/models/
# Out:
# PosixPath('/content/gdrive/My Drive/SeedlingRes50/stg-4-43-unf-1e54.pth')

# %% [markdown]
# #### lr = (1e-6, 1e-5)

# %%
learn.load('stg-3-large-1e43')  # which model to choose?
learn.data = data
learn.unfreeze()
learn.fit_one_cycle(4,max_lr=slice(1e-6,1e-5)) 
# 疑似过拟合
# Out:
# Total time: 23:15 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.078496</td>
#       <td>0.030891</td>
#       <td>0.011794</td>
#       <td>05:46</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.070444</td>
#       <td>0.033251</td>
#       <td>0.011794</td>
#       <td>05:49</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.074408</td>
#       <td>0.033446</td>
#       <td>0.012637</td>
#       <td>05:48</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.074812</td>
#       <td>0.032146</td>
#       <td>0.011794</td>
#       <td>05:50</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stg-4-43-unf-1e65', return_path=True) # not into path_data/models/
# Out:
# PosixPath('/content/gdrive/My Drive/SeedlingRes50/stg-4-43-unf-1e65.pth')

# %% [markdown]
# #### lr = (1e-4, 1e-3)

# %%
learn.load('stg-3-large-1e43')  # which model to choose?
learn.data = data
learn.unfreeze()
learn.fit_one_cycle(4,max_lr=slice(1e-4,1e-3)) 
# now, this looks great!
# Out:
# Total time: 23:55 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.148994</td>
#       <td>0.286620</td>
#       <td>0.105307</td>
#       <td>06:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.193353</td>
#       <td>0.210533</td>
#       <td>0.069924</td>
#       <td>05:56</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.114559</td>
#       <td>0.065902</td>
#       <td>0.022746</td>
#       <td>06:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.064416</td>
#       <td>0.047043</td>
#       <td>0.013479</td>
#       <td>05:59</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stg-4-43-unf-1e43', return_path=True) # not into path_data/models/
# Out:
# PosixPath('/content/gdrive/My Drive/SeedlingRes50/stg-4-43-unf-1e43.pth')

# %% [markdown]
# # 生成预测结果

# %% [markdown]
# #### stg-4-43-unf-1e43

# %%
# 加载模型，生成预测值
learn.load('stg-4-43-unf-1e43')
preds,y=learn.get_preds(ds_type=fv.DatasetType.Test)

# 每张图片提取最优结果，对应提取类别名称
preds = fv.np.argmax(preds, axis = 1)
preds_classes = [data.classes[i] for i in preds]

# 生成Kaggle格式 submission
import os
submission = fv.pd.DataFrame({ 'file': os.listdir('test'), 'species': preds_classes })
submission.to_csv('test_classification_results.csv', index=False)

# 确保所有打印内容能复制粘贴
with fv.pd.option_context('display.max_rows', None, 'display.max_columns', None):
#     print(df)
    display(submission) # 确保所有打印内容能复制粘贴
# Out:
#               file                    species
# 0    98da6ef4e.png          Scentless Mayweed
# 1    686dc7ec8.png                Black-grass
# 2    e15472085.png           Common Chickweed
# 3    05341a8a6.png          Scentless Mayweed
# 4    721be0a4a.png           Loose Silky-bent
# 5    800a8c17e.png                    Fat Hen
# 6    92292055d.png           Common Chickweed
# 7    6b721f68e.png                Black-grass
# 8    b31292706.png           Common Chickweed
# 9    bb7621cb3.png                    Fat Hen
# 10   bf3924a57.png           Common Chickweed
# 11   1f3f44563.png                      Maize
# 12   34dd57ca9.png           Loose Silky-bent
# 13   53ceb4657.png           Common Chickweed
# 14   7cabd68cc.png           Loose Silky-bent
# 15   6049234e6.png                    Fat Hen
# 16   808578ed5.png                   Charlock
# 17   22fbf13d6.png           Loose Silky-bent
# 18   cf90fc52d.png                      Maize
# ...

# %% [markdown]
# #### stg-4-43-unf-1e54

# %%
# 加载模型，生成预测值
learn.load('stg-4-43-unf-1e54')
preds,y=learn.get_preds(ds_type=fv.DatasetType.Test)

# 每张图片提取最优结果，对应提取类别名称
preds = fv.np.argmax(preds, axis = 1)
preds_classes = [data.classes[i] for i in preds]

# 生成Kaggle格式 submission
import os
submission = fv.pd.DataFrame({ 'file': os.listdir('test'), 'species': preds_classes })
submission.to_csv('test_classification_results.csv', index=False)

# 确保所有打印内容能复制粘贴
with fv.pd.option_context('display.max_rows', None, 'display.max_columns', None):
#     print(df)
    display(submission) # 确保所有打印内容能复制粘贴
# Out:
#               file                    species
# 0    98da6ef4e.png          Scentless Mayweed
# 1    686dc7ec8.png                Black-grass
# 2    e15472085.png           Common Chickweed
# 3    05341a8a6.png          Scentless Mayweed
# 4    721be0a4a.png           Loose Silky-bent
# 5    800a8c17e.png                    Fat Hen
# 6    92292055d.png           Common Chickweed
# 7    6b721f68e.png                Black-grass
# 8    b31292706.png           Common Chickweed
# 9    bb7621cb3.png                    Fat Hen
# 10   bf3924a57.png           Common Chickweed
# 11   1f3f44563.png                      Maize
# 12   34dd57ca9.png           Loose Silky-bent
# 13   53ceb4657.png           Common Chickweed
# 14   7cabd68cc.png           Loose Silky-bent
# 15   6049234e6.png                    Fat Hen
# 16   808578ed5.png                   Charlock
# 17   22fbf13d6.png           Loose Silky-bent
# 18   cf90fc52d.png                      Maize
# ...
